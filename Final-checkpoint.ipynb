# %% [markdown]
# # Analysis of Aviation Accident

# %% [markdown]
# ## Overview

# %% [markdown]
# For this project, I will use data cleaning, imputation, analysis, and visualization to generate insights for my company for its integration in the purchasing and operating airplanes for commercial and private enterprises,.

# %% [markdown]
# ## Business Understanding

# %% [markdown]
# Our company expands into the aviation sector, it is very important to begin with a clear understanding of the business objectives and associated risks. The primary goal is to identify and acquire aircraft that offer the lowest operational and safety risks while aligning with our strategic intent—whether in commercial passenger service, private charters, or both. This requires evaluating aircraft not just for initial cost, but for long-term reliability, safety record, regulatory compliance, and total cost of ownership. By establishing a strong foundation of risk-informed decision-making, we aim to ensure operational efficiency, protect our brand reputation, and position the aviation division for sustainable growth in a highly regulated and safety-sensitive industry.

# %%
import csv
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data Understanding

# %%
#Lecture du fichier csv
url="NTL-DS-Phase-1-Project-Template/Data/Aviation_Data.csv"
df=pd.read_csv(url,low_memory=False)

#Apercu du fichier
df.dtypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90348 entries, 0 to 90347
# Data columns (total 31 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Event.Id                88889 non-null  object
#  1   Investigation.Type      90348 non-null  object
#  2   Accident.Number         88889 non-null  object
#  3   Event.Date              88889 non-null  object
#  4   Location                88837 non-null  object
#  5   Country                 88663 non-null  object
#  6   Latitude                34382 non-null  object
#  7   Longitude               34373 non-null  object
#  8   Airport.Code            50132 non-null  object
#  9   Airport.Name            52704 non-null  object
#  10  Injury.Severity         87889 non-null  object
#  11  Aircraft.damage         85695 non-null  object
#  12  Aircraft.Category       32287 non-null  object
#  13  Registration.Number     87507 non-null  object
# ...

# %% [markdown]
# ## Data Preparation

# %% [markdown]
# #### Nettoyage des donnees

# %%
#
print(f"Lignes : {df.shape[0]}, Colonnes : {df.shape[1]}")

#Clean columns with 
df_clean=df.dropna(axis=1, thresh=0.7*len(df))

#Informations sur les donnees recuperees
df_clean.info()

# Examen des donnees supprimees 
df_clean.isnull().sum().sort_values(ascending=False).head(10)
# Out:
# Lignes : 90348, Colonnes : 31
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90348 entries, 0 to 90347
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Event.Id                88889 non-null  object
#  1   Investigation.Type      90348 non-null  object
#  2   Accident.Number         88889 non-null  object
#  3   Event.Date              88889 non-null  object
#  4   Location                88837 non-null  object
#  5   Country                 88663 non-null  object
#  6   Injury.Severity         87889 non-null  object
#  7   Aircraft.damage         85695 non-null  object
#  8   Registration.Number     87507 non-null  object
#  9   Make                    88826 non-null  object
#  10  Model                   88797 non-null  object
#  11  Amateur.Built           88787 non-null  object
#  12  Number.of.Engines       82805 non-null  float64
# ...

# %% [markdown]
# ## Analysis and Results

# %%
# Exemple : nombre d'accidents par type d'aéronef
df_clean['Engine.Type'].value_counts().plot(kind='bar', title="Nombre d’accidents par catégorie d'engin")
plt.xlabel("Type d'engin")
plt.ylabel("Nombre d'accidents")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()


# Nombre total d'accidents
total = df.shape[0]
print(f"Nombre total d'accidents : {total}")

# Répartition par type de vol
df["Purpose.of.flight"].value_counts().plot(kind="bar", title="Accidents par type de vol")
plt.ylabel("Nombre d'accidents")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

weather_counts = df["Weather.Condition"].value_counts()
weather_counts.plot(kind="pie", autopct="%1.1f%%", title="Conditions météo lors des accidents", ylabel="")
plt.tight_layout()
plt.show()

df["Broad.phase.of.flight"].value_counts().plot(kind="barh", title="Accidents par phase de vol")
plt.xlabel("Nombre d'accidents")
plt.tight_layout()
plt.show()
# Out:
# Nombre total d'accidents : 90348

# %% [markdown]
# ### Business Recommendation 1

# %% [markdown]
# Contrary to expectations, many accidents occured in favorable weather conditions VMC
# Strengthen training for pilots in all weather conditions

# %% [markdown]
# ### Business Recommendation 2

# %% [markdown]
# Encourage commercial flights instead of personal flights

# %% [markdown]
# ### Business Recommendation 3

# %% [markdown]
# Favor device with few serious accidents in the database.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# In this project, We've learned a lot about Aviation Accident and How to approach the Aviation sector and the risks for our company. In the Analysis of the data we've learned that is most careful to Avoid flights in adverse weather, Favor device with few serious accidents in the database and

# %% [markdown]
# ### Next Steps

# %% [markdown]
# Avoid investing in aircraft most often involved in personal accidents.

# %% [markdown]
# Focus on safe aircraft during cruise approach
